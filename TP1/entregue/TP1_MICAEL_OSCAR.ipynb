# %% [markdown]
# <table style="width: 100%; margin-left: auto; margin-right: auto; background-color: white;">
# <tbody>
# <tr>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Brasao_ufam_2011.jpg/375px-Brasao_ufam_2011.jpg" width="150" align="right">
#
# <td style="width: 68%;">
# <h2 style="text-align: center; margin-top: 1%;">Governo do Brasil</h2>
# <h2 style="text-align: center; margin-top: 1%;">Minist&eacute;rio da Educa&ccedil;&atilde;o</h2>
# <h2 style="text-align: center; margin-top: 1%;">Universidade Federal do Amazonas</h2>
# <h2 style="text-align: center; margin-top: 1%;">Instituto de Computa&ccedil;&atilde;o</h2>
# </td>
#
# <td style="width: 12%;"><img src="imagens/UFAM-logo.png" alt="" /></td>
#
# </tr>
# </tbody>
# </table>

# %% [markdown]
# # Paradigmas de Linguagem de Programação
# ### Lista de Exercícios / Trabalho Prático I
# #### Introdução e Programação Funcional, v. 1.0

# %% [markdown]
# Professor Dr. _Marco Cristo_
#
# **Alunos**:
#
# | nome | matrícula
# |:--:|:--:|
# | Micael Levi Lima Cavalcante  | 21554923 |
# | Oscar Othon Wanderley Siqueira Lima |21551563 |

# %% [markdown]
# ## Introdução & Contexto Histórico

# %% [markdown]
# #### Questão 1-1: O que caracteriza as quatro primeiras gerações de linguagens de programação? Dê exemplos de linguagens em cada uma destas gerações:

# %% [markdown]
# - Primeira geração (1995):
#   + código executado diretamente pela CPU (via _front panel_)
#   + baixa capacidade de abstração
#   + instruções usando apenas representação em números binários (0s e 1s)
#   + pouco intuitiva; difícil de interpretar e ler, mas apropriadas para máquinas
#   + referenciar variável (registrador) com endereço absoluto
#   + exemplo: Linguagem de máquina
#
# - Segunda geração (1965):
#   + linguagens de baixo nível
#   + notação legível para humanos do código de máquina utilizado para programar códigos para microprocessadores ou microcontroladores
#   + o código escrito pelo programador deveria ser convertido em um código legível por uma máquina -- processo chamado de "assembly" realizado por montadores
#   + linguagem específica a uma família particular de processadores e ambientes
#   + linguagens geralmente usadas em _kernel_ e dispositivos de _drivers_ mas adequada para processamento intensivos
#   + correspondência 1 por 1 entre o código programado e código gerado (resultante)
#   + exemplo: Assembly
#
# - Terceira geração (1972):
#   + linguagens de alto-nível
#   + independente da plataforma alvo
#   + linguagem projetada para ser facilmente lida por um ser humano (expressividade)
#   + inclusão de varáveis com nomes e definição de tipo de dados
#   + exemplo: Fortran, ALGOL, COBOL, C, Java, BASIC e Pascal
#
# - Quarta geração:
#   + constituem uma consolidação e correção de características na geração anterior, porém, com novas facilidades importantes
#   + linguagens que permitem ao programador especificar o que deve ser feito visando um resultado imediato
#   + suporte para gerenciamento de banco de dados, otimização de operações matemáticas e desenvolvimento web
#   + subconjunto de linguagens de domínio-específico (DSLs)
#   + exemplo: SQL, XML

# %% [markdown]
# #### Questão 1-2: Por que linguagens modernas tendem a suportar múltiplos paradigmas?

# %% [markdown]
# Devido ao surgimento de problemas de natureza distintas que um mesmo programa geralmente enfrenta, oferecer suporte a vários paradigmas possibilita que a base de código se mantenha com o uso de poucas linguagens envolvidas, de modo a facilitar a manutenção e interação entre diferentes partes do desenvolvimento. Isso é posível pois diferentes problemas para uma mesma solução podem ser pensados em um paradigma mais adequado.
#
# Percebendo os erros cometidos em linguagens clássicas, as modernas surgem com melhorias gradativas que evoluem com o tempo, corrigindo decisões de projetos e funcionalidades que impactavam negativamente na popularidade e utilidade da linguagem após alguns anos de inovação tecnológica.
#
# Além disso, a popularidade de uma linguagem de programação está relacionada aos conceitos que serão utilizados nela -- flexibilidade. Assim, desenvolvedores experientes em diferentes linguagens e, naturalmente, paradigmas, serão mais facilmente alcançados.

# %% [markdown]
# #### Questão 1-3: Embora `Simula67` tenha introduzido os conceitos de classes, objetos e herança, normalmente `Smalltalk` é descrita como a primeira linguagem Orientada à Objetos. Por quê?

# %% [markdown]
# A Simula67 não introduziu a noção de O.O., apenas considerava que alguns problemas poderiam ser solucionados com a P.O.O., onde diferentes agentes formavam um objeto global. É uma extensão do Algol 60 que usava tanto a estrutura em bloco como a estrutura de instrução de controle definidas nela, mas corrigindo um problema comum da época dando suporte a co-rotinas (_onde subprogramas chamadores e chamados têm uma relação igual entre si, diferente da hierárquica_). Para oferecer tal suporte, desenvolveu-se a construção de **classe**, assim como criou a noção de objetos e sub-classes,  proporcionando novas ideias sobre a abstração de dados. A herança aparece de forma limitada. Enquanto o Smalltalk, traz os objetos como unidades do programa, além de incluir os conceitos que tornam a solução de problemas orientados a objeto possível, conveniente e efetiva.

# %% [markdown]
# #### Questão 1-4: Pesquise sobre `Fortran` e `Julia`. O que há de comum entre elas? E que alternativas de projeto adotadas por Julia a separam de Fortran?

# %% [markdown]
# As linguagens de programação Julia e Fortran (moderno) têm os seguintes aspectos em comum:
# - alto nível
# - compiladas
# - suporte a vários paradigmas
# - programação em alto nível
# - projetadas com foco em computação científica (física) e numérica de alto desempenho
# - ecossistema com um gerenciador de pacotes
#
# Julia adota usa compilação LLVM _Just In Time_ (JIT), otimizado para a CPU e S.O.. Utiliza estatísticas sobre o programa para rearranjar e recompilar proporcionando um melhor desempenho.
#
# Dedivo à capacidade de definir o comportamento de funções com base na combinação de vários tipos de argumentos via _multiple dispatch_ (multi-métodos), e ao foco no desempenho, a eficiência computacional de Julia é suporior que a de outras linguagens dinâmicas e se aproxima de linguagens estáticas e compiladas. Além de um melhor suporte a _arrays_ multidimensionais, tornando-a adequada para códigos de Análise de Elementos Finitos (FEA). Assim, a modelagem computacional, paralela e distribuída, torna-se facilitada. Porém, não é recomendada projetos com códigos de pesquisas em larga escala que serão executadas em um _cluster_. Julia oferece um suporte eficiente para Unicode não limitado ao UTF-8, o que não acontece com o Fortran (moderno) e extensibilidade de tipos numéricos, para melhorar a precisão.
#
# Ainda há outras ferramentas que não existem no Fortran mas foram adotadas nativamente em Julia, tais utilitários, como: macros para metaprogramação, são possíveis apenas com extensões da linguagem.

# %% [markdown]
# #### Questão 1-5: Compare os mecanismos de tratamento de exceção de C, Python e Go. Que problemas na estratégia do C estimularam aquela adotada em Python? Da mesma forma, como as decisões tomadas em Go foram influenciadas pelas características do modelo usado no Python?

# %% [markdown]
# ##### exemplo em C
# ```c
# // mecanismo usando retorno (sem instruções específicas e dereferência)
# int get_number(char *fname, long *val) {
# 	char *s, *sval, *endptr;
# 	FILE *f = fopen(fname, “r”);
# 	if  (f == NULL) {
# 		perror(“Error”);
# 		return ERROR_IO;
# 	}
# 	fgets(s, MAX_STRING, f);
# 	if (ferror(f) || feof(f)) {
# 		perror(“Error”);
# 		fclose(f);
# 		return ERROR_IO;
# 	}
# 	sscanf(s, “%s”, sval);
# 	val = strtol(sval, &endptr, 10);
# 	if (ERANGE == 0) {
# 		fprintf(stderr, "Input number doesn't fit into long\n");
# 		fclose(f);
# 		return ERROR_RANGE;
# 	} else if (*endptr) {
# 		fprintf(stderr, "%s is not a valid long number\n“, sval);
# 		fclose(f);
# 		return ERROR_VALUE;
# 	}
# 	fclose(f);
# 	return NO_ERROR;
# }
# ```
#
# ##### exemplo em Go
# ```golang
# // "nem todo erro é uma exceção pra tratamento assíncrono"
# // func Open(name string) (file *File, err error)
# f, err := os.Open("filename.ext")
# if err != nil {
#     log.Fatal(err)
#     return err
# }
# defer f.Close()
# ```
#
# ##### exemplo em Python
# ```python
# try:
#     f = open('integers.txt')
#     try:
#       s = f.readline()
#       i = int(s.strip())
#     finally:
#       f.close()
# except IOError as e:
#     errno, strerror = e.args
#     print("I/O error({0}): {1}".format(errno,strerror))
# except ValueError:
#     print("No valid integer in line.")
# except:
#     print("Unexpected error:", sys.exc_info()[0])
#     raise
# ```

# %% [markdown]
# A linguagem C não oferece um mecanismo real de tratamento de exceções, o método usado para verificar se o fluxo ideal pode ser continuado ou não se dá através de verificações de retorno de chamada de funções e/ou checagem de variáveis externas nativas que podem indicar erros que podem ocorrer ao se utilizar recursos do sistema operacional. Além da verificações de sinais de exceção lançados em tempo de execução.  Os problemas dessa estratégia que podem ter estimulado no mecanismo usado em Python são:
# - necessidade de um conhecimento prévio sobre as variáveis de erros que serão em cenários que podem causar exceções
# - necessidade de várias condições para testar diferentes exceções que podem ser identificadas, o que pode aumentar o código de um programa simples, impactando na leitura
# - desvios de fluxo difíceis de identificar
# - ausência de instruções dedicadas (várias formas de tratar)
# - erros difíceis de serem encontrados e depurados
#
# Na linguagem Go, o uso de retornos de função como tuplas acompanhadas com possíveis erros oferecem uma melhoria significativa em relação à estratégia usada no C e uma legibilidade em casos onde o bloco `try-catch` do Python tenderia a ficar extenso (e mais verboso). A palavra reservada `defer` em Go, proporciona um substituição do `try-finally` do Python com uma maior segurança pois garante que um trecho será executado quando a função onde ele está retornar. Além de reduzir o número de chamadas de uma função que deverá liberar um recurso sempre que um problema é identificado mas em diferentes trechos do código.

# %% [markdown]
# ## Programação Funcional em `Python 2`

# %% [markdown]
# ### Aquecimento

# %%
from __future__ import division, print_function

# %% [markdown]
# #### Questão 2-1
# Defina os seguintes conceitos como são compreendidos no paradigma funcional: (a) funções anônimas, (b) funções de primeira classe, (c) funções de alta ordem, (d) funções recursivas, (e) funções puras, (f) avaliação preguiçosa, (g) iteradores e (h) geradores ou streams.

# %% [markdown]
# a. **funções anônimas**:
# Funções definidas sem um nome associado. Normalmente usadas como expressões que serão avaliadas apenas uma vez. Diminuindo, assim, o _overhead_ causado pela existência de mais uma função no escopo. Geralmente limitadas a uma única instrução que recebem algo, realiza um processamento simples e  o retorna.
#
# b. **funções de primera classe:**
# Quando funções são tratadas como "objetos de primeira-classe". Ou seja, são como qualquer outro tipo de dados, assim, podem ser passadas para outras funções como argumento, retornadas por elas e atribuídas como valor à variáveis.
#
# c. **funções de alta ordem:**
# São funções que trabalham com funções de primeira classe, isto é, recebem funções como argumento e/ou retornam funções. Exemplo: `map`, `filter` e `reduce`.
#
# d. **funções recursivas:**
# Usado como método de iteração onde uma função é definida usando ela mesma. Na prática, é uma função que chama a si própria até que não seja mais necessário (atingir um caso base).
#
# e. **funções puras:**
# Funções que geram uma saída em função unicamente dos dados de entrada. Além de não produzirem efeitos colaterais. Proporciando a Transparência Referencial, que é a capacidade de substituir uma chamada da função pelo seu valor, já que a função terá a mesma saída sempre que forem passados as mesmas entradas.
#
# f. **avaliação preguiçosa:**
# Capacidade de avaliar uma expressão o mais tarde possível -- somente quando for realmente necessário. Tornando a modularização vivável, já que é possível construir diversos cenários sem consumir os recursos gerados por todos eles ao mesmo tempo. Além da capacidade de representar potencialmente estruturas de dados infinitas.
#
# g. **iteradores:**
# Recurso da Computação Preguiçosa, usados como uma forma de processar uma série/sequência de elementos. Retornam uma sequência de dados que são gerados por demanda, elemento a elemento, as _streams_.
#
# h. **geradores:**
# São expressões que criam (geram) iteradores. Exemplo a função _built-in_ do Python2 `xrange`.

# %% [markdown]
# #### Questão 2-2: soma de quadrados
# Usando LCs, defina a função `soma_quadrados(n)` que retorna a soma dos quadrados dos n primeiros números inteiros. Ex: `soma_quadrados(5) == 30`.

# %%
def soma_quadrados(n):
  somar = lambda x, y: x+y
  quadrado = lambda n: n**2
  return reduce(somar, [ quadrado(n) for n in range(1, n) ])



#--------------------------------------------------------#
soma_quadrados(5) == 30
# Out:
# True

# %% [markdown]
# #### Questão 2-3: números perfeitos
# Um número inteiro positivo é _perfeito_ se ele é a soma de todos os seus fatores, excluído o próprio número. Escreva a função `perfeitos(n)` que retorna todos os números perfeitos entre os ***n***  primeiros números inteiros. Ex: `perfeitos(10000) = [6, 28, 496, 8128]`.

# %%
def perfeitos(n):
  divisivel = lambda n, x: n % x == 0
  fatores = lambda n: ( x for x in range(1, n) if divisivel(n, x) )

  return [
      x for x
      in range(1, n)
      if sum( fatores(x) ) == x
  ]



#--------------------------------------------------------#
perfeitos(10000) == [6, 28, 496, 8128]
# Out:
# True

# %% [markdown]
# #### Questão 2-4: índices na lista como função de alta ordem
# Usando recursão, implemente a função `indices_na_lista(lst, el, comp)` que retorna os índices na lista `lst`, que satisfazem a comparação com o elemento `el`, de acordo com o comparador `comp`.
#
# Exs:
# - `indices_na_lista([10, 20, 30, 20, 10], 20, lambda x, y: x == y) == [1, 3]`
# - `indices_na_lista([10, 20, 30, 20, 10], 20, lambda x, y: x < y) == [0, 4]`
# - `indices_na_lista(['10', 20, '30', '20', 10], '20', lambda x, y: x == y if type(x) == type(y) else False) == [3]`

# %%
def indices_na_lista(lst, el, comp):
  def iterate_from_index(i, limit):
    return [] if i == limit else \
           ( [i] if comp(lst[i], el) else [] ) + iterate_from_index(i + 1, limit)

  return iterate_from_index(0, len(lst))



#--------------------------------------------------------#
indices_na_lista([10, 20, 30, 20, 10], 20, lambda x, y: x == y) == [1, 3], \
indices_na_lista([10, 20, 30, 20, 10], 20, lambda x, y: x < y) == [0, 4],  \
indices_na_lista(['10', 20, '30', '20', 10], '20', lambda x, y: x == y if type(x) == type(y) else False) == [3]
# Out:
# (True, True, True)

# %% [markdown]
# #### Questão 2-5: busca binária como função de alta ordem
# Usando recursão, implemente a função `busca_binaria(lst, chave, seletor_chave, f_igual, f_maior)`.
#
# Esta função usa busca binária para encontrar uma `chave` em `lst`. Se encontrar, ela retorna o elemento correspondente em `lst`. Como `lst` é uma lista de tipos arbitrários, `busca_binaria` usa a função `seletor_chave` para obter a chave de um elemento da lista; usa as funções `f_igual` e `f_maior` para comparar a chave dada com a chave do elemento, determinando assim se são iguais ou se a primeira é maior que a segunda. Abaixo, temos exemplos de uso da função:
#
# ```python
# from string import lower
#
# # primeiro, um exemplo simples
# print (busca_binaria([10, 15, 17, 19, 23, 31, 37, 43, 67, 81, 94], 19)) # 19
#
# # agora, um exemplo mais complexo com tuplas como elementos;
# # chave em ordem decrescente e mix entre minusculas e maiusculas
# dados = [(10, 'Tiago'), (15, 'Renato'), (17, 'Paula'),
#          (19, 'marcelo'), (23, 'joao'), (31, 'nubia'),
#          (37, 'Keila'), (43, 'Eduardo'), (67, 'Denys'),
#          (81, 'Beatriz'), (94, 'ana')]
# print (busca_binaria(dados, 'ana', seletor_chave = lambda x: lower(x[1]),
#                     f_maior = lambda x, y: x < y)) # (94, 'ana')
# ```

# %%
identity = lambda x: x
equal    = lambda x, y: x == y
greater  = lambda x, y: x > y

def busca_binaria(lst, chave, seletor_chave=identity, f_igual=equal, f_maior=greater):
  if not lst:
    return None

  meio = len(lst) // 2
  e = seletor_chave(lst[meio])

  return lst[meio] if f_igual(e, chave)  \
         else busca_binaria(lst[:meio] if f_maior(e, chave) else lst[meio + 1:],
                            chave, seletor_chave, f_igual, f_maior)



#--------------------------------------------------------#
print( busca_binaria([10, 15, 17, 19, 23, 31, 37, 43, 67, 81, 94], 19) == 19 )

dados = [(10, 'Tiago'),   (15, 'Renato'),  (17, 'Paula'), 
         (19, 'marcelo'), (23, 'joao'),    (31, 'nubia'), 
         (37, 'Keila'),   (43, 'Eduardo'), (67, 'Denys'), 
         (81, 'Beatriz'), (94, 'ana')]

from string import lower
print( busca_binaria(dados, 'ana',
                     seletor_chave=lambda x: lower(x[1]),
                     f_maior=lambda x, y: x < y) == (94, 'ana') )
# Out:
# True
# True

# %% [markdown]
# ### Um Interpretador $\mu$Forth

# %% [markdown]
# Nesta série de exercícios, vamos implementar um interpretador para a linguagem $\mu$Forth, usando Python funcional.

# %% [markdown]
# Como Forth, $\mu$Forth é uma linguagem baseada em pilha. Um programa em $\mu$Forth é uma sequência de instruções que modificam uma pilha. Cada instrução se refere a uma palavra previamente definida ou a definição de uma nova palavra. Por exemplo, no programa abaixo:
#
# ```
# 3 4 +
# ```
#
# há três palavras, os números 3 e 4 e o sinal +. Os números 3 e 4 são inseridos na pilha. A palavra + indica que os dois números no topo da pilha (4, 3; 4 no topo) serão desempilhados, somados (+) e o resultado (7) será inserido na pilha. Assim, dada uma pilha vazia, após a execução de “3 4 +”, ela passa a ter um elemento, 7. A seguir, um exemplo mais complexo:
#
# ```
# : quadrado dup * ;
# 3 quadrado
# ```
#
# Na primeira linha é definida a palavra quadrado. Definições são iniciadas com um ‘:’ (dois-pontos). A palavra definida será substituída por todas as palavras até um ‘;’ (ponto-e-vírgula). No exemplo, a definição de quadrado duplica o valor no topo da pilha (palavra reservada `dup`) e então multiplica os dois elementos do topo (palavra `*`). Ou seja, após a execução de quadrado, o valor que estava no topo da pilha é substituído por seu quadrado. Na segunda linha, o valor 3 é inserido na pilha e a palavra quadrado é aplicada, de forma que o valor 3 é substituído por 9.

# %% [markdown]
# #### Questão 3-1: uma pilha funcional
# Vamos iniciar nossa implementação criando funções de manipulação de pilha  `empty` (verifica se pilha está vazia),  `push` (insere elemento no topo da pilha),  `pop` (retira o elemento no topo da pilha) e `top` (retorna o valor no topo da pilha), em estilo funcional. Ou seja, as funções recebem a pilha e a retornam modificada, de acordo com a operação executada. Veja os exemplos abaixo de uso:
#
# ```python
# ex_stack = [10, 20, 30, 40] # 40 é o topo da pilha
# print(empty(ex_stack)) # False
# print(push(ex_stack, 50)) # [10, 20, 30, 40, 50]
# print(pop(ex_stack)) # [10, 20, 30]
# print(top(ex_stack)) # 40
# ```

# %%
def empty(s):
  'retorna True se a pilha passada for vazia. False caso contrário'
  return len(s) == 0

def push(stack, e):
  'empilha um elemento na pilha (o topo é o último da lista)'
  return stack + [e]

def pop(stack):
  'desempilha um elemento da pilha'
  return stack[:-1]

def top(stack):
  'retorna o topo da pilha ou None se ela estiver vazia'
  return stack[-1] if not empty(stack) else None



#--------------------------------------------------------#
ex_stack = [10, 20, 30, 40]
empty(ex_stack) == False,                   \
push(ex_stack, 50) == [10, 20, 30, 40, 50], \
pop(ex_stack) == [10, 20, 30],              \
top(ex_stack) == 40
# Out:
# (True, True, True, True)

# %% [markdown]
# #### Questão 3-2: separando listas
# Usando recursão, implemente a função `split_val`, que dada uma lista e um elemento $v$, ela retorna uma lista formada por todos os elementos observados até antes da primeira ocorrência de $v$ e uma lista com os elementos restantes, incluindo $v$. Esta função será útil para analisar sequências de palavras em Forth. Veja os exemplos a seguir:
#
# ```python
# print(split_val([], 1)) # ([], [])
# print(split_val([1], 1)) # ([], [1])
# print(split_val([2], 1)) # ([2], [])
# print(split_val([1, 2, 3], 1)) # ([], [1, 2, 3])
# print(split_val([1, 2, 3], 2)) # ([1], [2, 3])
# print(split_val([1, 2, 3], 3)) # ([1, 2], [3])
# ```

# %%
def split_val(l, v):
  if not l or l[0] == v:
    return ([], l)

  lanteriores, lresto = split_val(l[1:], v)
  return (l[:1] + lanteriores, lresto)



#--------------------------------------------------------#
split_val([], 1) == ([], []),               \
split_val([1], 1) == ([], [1]),             \
split_val([2], 1) == ([2], []),             \
split_val([1, 2, 3], 1) == ([], [1, 2, 3]), \
split_val([1, 2, 3], 2) == ([1], [2, 3]),   \
split_val([1, 2, 3], 3) == ([1, 2], [3])
# Out:
# (True, True, True, True, True, True)

# %% [markdown]
# #### Questão 3-3: funções unárias e binárias
# Crie as funções `bin_op(s, fb)` e `una_op(s, fu)` que, dados uma pilha `s` e funções `fb` e `fu`, elas retornam a pilha resultante da execução das operações binárias e unárias, respectivamente. Implemente estas funções usando as funções de operação em pilha que você implementou antes. Veja os exemplos a seguir:
#
# ```python
# print(bin_op([0, 1, 2, 3], lambda x, y: x + y)) # [0, 1, 5]
# print(una_op([0, 1, 2, 3], lambda x: x*x)) # [0, 1, 2, 9]
# ```

# %%
def bin_op(s, fb): ## usa o topo como primeiro operando
  if empty(s):
    return []
  new_s = pop(s)
  return push( pop(new_s), fb(top(s), top(new_s)) )


def una_op(s, fu):
  return [] if empty(s) else push( pop(s), fu(top(s)) )



#--------------------------------------------------------#
bin_op([0, 1, 2, 3], lambda x, y: x + y) == [0, 1, 5],  \
una_op([0, 1, 2, 3], lambda x: x*x) == [0, 1, 2, 9]
# Out:
# (True, True)

# %% [markdown]
# #### Questão 3-4: swap
# Crie a função `swap(s)` que, dada uma pilha `s`, ela retorna a pilha resultante com os dois primeiros elementos trocados. Implemente estas funções usando as funções de operação em pilha que você implementou antes. Veja o exemplo a seguir:
#
# ```python
# print(swap([0, 1, 2, 3])) # [0, 1, 3, 2]
# ```

# %%
def swap(s):
  if empty(s):
    return []
  if len(s) < 2: ## tratando uma exceção
    return s[:]
  new_s = pop(s)
  return push( push( pop(new_s), top(s) ), top(new_s) )



#--------------------------------------------------------#
swap([0, 1, 2, 3]) == [0, 1, 3, 2]
# Out:
# True

# %% [markdown]
# #### Questão 3-5: roll
# Crie a função `roll(s)` que opera sobre uma pilha `s`. Esta função rotaciona o $i$-ésimo elemento de uma pilha para o seu topo. Para tanto, ela inicialmente considera que o valor no topo da pilha corresponde à posição $i$ do restante da pilha. Ela então move o $i$-ésimo elemento para o topo. Implemente esta função usando as funções de operação em pilha que você implementou antes. Veja o exemplo a seguir:
#
# ```python
# # No exemplo abaixo, 2 corresponde à 3a posicao da pilha sem o 2, ou seja, a posição do 10
# print(roll([10, 20, 30, 2])) # [20, 30, 10]
# ```

# %%
def roll(s):
  if empty(s):
    return []
  if top(s) > len(s): ## guard clasue para evitar exceções
    return s[:]

  def split_until_0(i, sin, sout):
    ## Desempilha `sin` em `sout` enquanto `i` for maior que 1
    return (sin, sout) if i < 1 \
           else split_until_0( i - 1, pop(sin), push(sout, top(sin)) )

  def repush(sin, sout):
    ## Desempilha os elementos de `sin`, empilhando-os em `sout`
    return sout if empty(sin) \
           else repush( pop(sin), push(sout, top(sin)) )

  sin, sout = split_until_0(top(s), pop(s), [])
  return push( repush(sout, pop(sin)), top(sin) )



#--------------------------------------------------------#
roll([10, 20, 30, 2]) == [20, 30, 10]
# Out:
# True

# %% [markdown]
# #### Questão 3-6: executando primitvas ou interpretador versão 0
# O $\mu$Forth é uma linguagem que opera, em geral, com duas pilhas, uma pilha de trabalho e uma de resultados. Quase todas as operações são mediadas pela pilha de trabalho. Contudo, resultados intermediários podem ser armazenados na pilha de resultados, que funciona como uma memória auxiliar. Abaixo, implementamos algumas das primitivas do  $\mu$Forth (`.`, `drop`, `rempty`, `sqrt` e `+`):
#
# | **Palavra** | **Definição** |
# |:--|:--|
# | **.** | Exibe topo da pilha na tela|
# | **+ sqrt** | Soma e raíz quadrada |
# | **rempty** | Empilha 1 se pilha de resultados vazia (0, se não) |
# | **drop** | Desempilha valor no topo da pilha (3 4 2 1 -> 4 2 1), 3 está no topo |

# %% [markdown]
# Modifique `primitives` para suportar as seguintes palavras $\mu$Forth, além das já suportadas:

# %% [markdown]
# | **Palavra** | **Definição** |
# |:--|:--|
# | **disp** | Exibe na tela as pilhas de trabalho e de resultados (ajuda com debug) |
# | **- * / %** | Subtração, multiplicação, divisão e resto |
# | **> < =** | Empilha 0 ou 1 de acordo com operador maior, menor ou igual |
# | **or and not** | Empilha 0 ou 1 de acordo com operador relacional ou, e e não |
# | **empty** | Empilha 1 se pilha de trabalho está vazia (0, se não) |
# | **swap** | Troca valores no topo (3 4 2 1 -> 4 3 2 1) |
# | **dup** | Duplica valor no topo (3 4 2 1 -> 3 3 4 2 1) |
# | **roll** | Move n-esimo valor pro topo (1 roll com 5 6 7 -> 6 5 7) |
# | **>r** | Move topo da pilha de trabalho pra pilha de resultados |
# | **r>** | Move topo da pilha de resultados pra pilha de trabalho |
# | **r@** | Copia topo da pilha de trabalho pra pilha de resultados |

# %% [markdown]
# __Observações__:
# - Números em $\mu$Forth podem ser inteiros (ex: 7) ou reais (ex: 3.14) e podem ser negativos (ex: -7 ou -3.14).
# - Em geral, todos os comandos consomem os elementos da pilha que utilizam (`r@` é uma exceção).
# > Por exemplo, se a pilha tem os elementos 5 (topo), 4, 3, após a execução de `*`, os elementos 5 e 4 são consumidos e substituídos por seu produto, 20. Assim, a pilha fica com os elementos 20 e 3.
#
# - Operados lógicos e relacionais sempre deixam um valor `0` (falso) ou `1` (verdadeiro) no topo da pilha.
# > Por exemplo, se a pilha tem 10 (topo), 11, 3, o operador `>` deixa o valor `1` no topo da pilha pois 11 é maior que 10. A pilha ficaria então com 1, 3.
#
# - A palavra `roll` não considera o valor no topo da pilha (usando como índice) no cálculo do elemento que devem processar.
# > Por exemplo, dada a pilha 10 (topo), 11, 12, 13, as palavras `2 roll` indicam que o elemento 2 da pilha (elemento 12 já que o elemento 0 é o topo 10) deve ser movida pro topo. Logo a pilha fica com 12, 10, 11, 13.

# %% [markdown]
# ##### respostas:

# %%
## ========================================================================== ##
## ========================== fornecido pelo prof =========================== ##
def top_value(s):
  'shows working stack top (`?` if working stack is empty)'
  return '?' if empty(s) else '%f' % top(s) if top(s)%1 != 0 else '%d' % top(s)

def dot(ws):
  'pops working stack top and show it'
  print(top_value(ws), end='')
  return pop(ws)
## ========================================================================== ##


WS = lambda stacks: stacks[0] ## retorna a Working Stack
RS = lambda stacks: stacks[1] ## retorna a Stack de resultados



def _disp(stacks):
  'exibe na tela as duas pilhas, sem consumi-las'
  print('working stack =', WS(stacks))
  print('result  stack =', RS(stacks))
  return [ WS(stacks), RS(stacks) ]

def _sub(stacks):
  'realiza a subtração dos dois valores no topo da pilha de trabalho'
  return [ bin_op(WS(stacks), lambda x,y: x-y),
           RS(stacks) ]

def _mul(stacks):
  'realiza a multiplicação dos dois valores no topo da pilha de trabalho'
  return [ bin_op(WS(stacks), lambda x,y: x*y),
           RS(stacks) ]

def _div(stacks):
  'realiza a divisão dos dois valores no topo da pilha de trabalho'
  return [ bin_op(WS(stacks), lambda x,y: x/y),
           RS(stacks) ]

def _mod(stacks):
  'realiza a operação de resto entre os dois valores no topo da pilha de trabalho'
  return [ bin_op(WS(stacks), lambda x,y: x%y),
           RS(stacks) ]

def _greater_than(stacks):
  'substitui os dois valores do topo da pilha de trabalho pela comparação MAIOR QUE entre eles (1 ou 0)'
  result_stack = bin_op(WS(stacks), lambda x,y: y>x) ## o topo é o segundo operando
  return [ push( pop(result_stack), +top(result_stack) ),
           RS(stacks) ]

def _less_than(stacks): ## não trata divisões por 0
  'substitui os dois valores do topo da pilha de trabalho pela comparação MENOR QUE entre eles (1 ou 0)'
  result_stack = bin_op(WS(stacks), lambda x,y: y<x) ## o topo é o segundo operando
  return [ push( pop(result_stack), +top(result_stack) ),
           RS(stacks) ]

def _equal(stacks):
  'substitui os dois valores do topo da pilha de trabalho pela comparação IGUAL entre eles (1 ou 0)'
  result_stack = bin_op(WS(stacks), lambda x,y: x==y)
  return [ push( pop(result_stack), +top(result_stack) ),
           RS(stacks) ]

def _or(stacks):
  'substitui os dois valores do topo da pilha de trabalho pela comparação OR (do python) entre eles (1 ou 0)'
  result_stack = bin_op(WS(stacks), lambda x,y: x or y)
  return [ push( pop(result_stack), +top(result_stack) ),
           RS(stacks) ]

def _and(stacks):
  'substitui os dois valores do topo da pilha de trabalho pela comparação AND (do python) entre eles (1 ou 0)'
  result_stack = bin_op(WS(stacks), lambda x,y: x and y)
  return [ push( pop(result_stack), +top(result_stack) ),
           RS(stacks) ]

def _not(stacks):
  'substitui o valor do topo da pilha de trabalho pela operação NOT (do python) sobre ele (1 ou 0)'
  result_stack = una_op(WS(stacks), lambda x: not x)
  return [ push( pop(result_stack), +top(result_stack) ),
           RS(stacks) ]

def _empty(stacks):
  'substitui o valor do topo da pilha de trabalho por 1 se ela estiver vazia ou 0, caso contrário'
  return [ push( WS(stacks), +empty(WS(stacks)) ),
           RS(stacks) ]

def _swap(stacks):
  'troca os valores no topo da pilha de trabalho'
  return [ swap( WS(stacks) ),
           RS(stacks) ]

def _dup(stacks):
  'duplica o valor do topo da pilha de trabalho'
  ws = WS(stacks)
  return [ [] if empty(ws) else push(ws, top(ws)),
           RS(stacks) ]

def _roll(stacks):
  'move o n-ésimo valor por topo, onde n é o valor corrente do topo da pilha de trabalho'
  return [ roll( WS(stacks) ),
           RS(stacks) ]

def _move_ws_to_rs(stacks):
  'move o topo da pilha de trabalho para a pilha de resultados'
  return stacks[:] if empty( WS(stacks) )  \
         else [ pop( WS(stacks) ),
                push( RS(stacks), top(WS(stacks)) ) ]

def _move_rs_to_ws(stacks):
  'move o topo da pilha de resultados para a pilha de trabalho'
  return stacks[:] if empty( RS(stacks) )  \
         else [ push( WS(stacks), top(RS(stacks)) ),
                pop( RS(stacks) ) ]

def _copy_ws_to_rs(stacks):
  'copia o topo da pilha de trabalho para a pilha de resultados (sem consumir)'
  return stacks[:] if empty( WS(stacks) )  \
         else [ WS(stacks),
                push( RS(stacks), top(WS(stacks)) ) ]

# %% [markdown]
# ##### testando as `primitives`

# %%
from math import sqrt

primitives = {
  # The two Forth stacks (working and results) are represented by a list with two values.
  # Each Forth primitive receives the two stacks, modifying them if necessary.
  # -- dot: calls dot to show working stack top value (value is consumed)
  '.':      lambda stacks: [ dot(WS(stacks)), RS(stacks) ],
  # -- drop: drops element from working stack
  'drop':   lambda stacks: [ pop(WS(stacks)), RS(stacks) ],
  # -- rempty: pushes 1 to working stack if result stack is empty; 0, otherwise 
  'rempty': lambda stacks: [ push(WS(stacks), int(empty(RS(stacks)))), RS(stacks) ],
  # -- sqrt: substitutes the top of the working stack value by its square root 
  'sqrt':   lambda stacks: [ una_op(WS(stacks), sqrt), RS(stacks) ],
  # -- +: substitutes the two top values in working stack by their sum
  '+':      lambda stacks: [ bin_op(WS(stacks), lambda x,y: x+y), RS(stacks) ],

  ######################### RESPOSTAS DA QUESTÃO 3-6 #########################
    
  # -- disp: exibe na tela as pilhas de trabalho e de resultados (sem consumir)
  'disp': _disp,
  # -- -: realiza a subtração na pilha de resultados
  '-': _sub,
  # -- *: realiza a mutiplicação na pilha de resultados
  '*': _mul,
  # -- /: realiza a divisão na pilha de resultados
  '/': _div,
  # -- %: realiza a operação de resto (MOD) na pilha de resultados
  '%': _mod,
  # -- >: empilha 0 ou 1 de acordo com a saída da operação lógica MAIOR QUE
  '>': _greater_than,
  # -- <: empilha 0 ou 1 de acordo com a saída da operação lógica MAIOR QUE
  '<': _less_than,
  # -- =: empilha 1 se os dois valores do topo forem iguais ou 0 caso contrário
  '=': _equal,
  # -- or: empilha 0 ou 1 de acordo com a saída do operador relacional OR
  'or': _or,
  # -- and: empilha 0 ou 1 de acordo com a saída do operador relacional NOT
  'and': _and,
  # -- not: empilha 0 ou 1 de acordo com a saída do operador relacional NOT
  'not': _not,
  # -- empty: empilha 1 se pilha de trabalho está vazia (0, caso contrário)
  'empty': _empty,
  # -- swap: troca valores no topo da pilha de trabalho
  'swap': _swap,
  # -- dup: duplica o valor do topo da pilha de trabalho
  'dup': _dup,
  # -- roll: move o n-ésimo valor por topo (1 roll com 5 6 7 -> 6 5 7)
  'roll': _roll,
  # -- >r: move o topo da pilha de trabalho pra pilha de resultados
  '>r': _move_ws_to_rs,
  # -- r>: move o topo da pilha de resultados pra pilha de trabalho
  'r>': _move_rs_to_ws,
  # -- r@: copia o topo da pilha de trabalho pra pilha de resultados (sem consumir)
  'r@': _copy_ws_to_rs
}


## given the Forth stacks, run applies word to them outputing the modified stacks
def run(stacks, word):
  print('►', word)
  if word not in primitives:
    raise Exception('Primitiva `{}` não implementada!'.format(word))
  return primitives[word](stacks)

# %% [markdown]
# #### Questão 3-7: um interpretador Forth
#
# Agora que várias palavras da linguagem estão implementadas, podemos escrever uma primeira versão do nosso interpretador. Além das primitivas já descritas, nosso interpretador ainda irá suportar as palavras:

# %% [markdown]
# | **Palavra** | **Definição** |
# |:--|:--|
# | **:** palavra Seq **;**| Define palavra como sequencia de outras palavras (Seq) |
# | numero|Insere número na pilha de trabalho|
# | **.''** string **"** | Exibe string na tela|
# | **cr** | Salta uma linha (mesmo que imprimir ‘\n’ no C/C++)|

# %% [markdown]
# Agora é a sua vez. **Expanda o interpretador para suportar as seguintes primitivas:**

# %% [markdown]
# | **Palavra** | **Definição** |
# |:--|:--|
# | **begin** Seq Cond **until** | Repete Seq (sequência de palavras) até condição Cond ser satisfeita |
# | Cond **if** Seq1 [**else** Seq2] **then** | Executa Seq1 se Cond é verdadeira (senão executa Seq2, se definida) |
#
# **OBS:** `begin` marca o início do laço (do-while) e `until` marca o final

# %%
## ========================================================================== ##
## ========================== fornecido pelo prof =========================== ##
def new_def(defs, word, seq):
  "Associates a word with a seq of Forth words provided by the user, using a Python's map called defs"
  defs[word] = seq
  return defs

def is_number(s):
  "Checks if s is a number"
  try:
    float(s)
    return True
  except ValueError:
    return False
## ========================================================================== ##

  

def exec_begin_until_for(interpret):
  def exec_begin_until(proc_body, stacks, defs):
    if empty(proc_body): ## tratando o caso onde o corpo do `begin..until` não foi definido
      return (stacks, defs)

    n_stacks, n_defs = interpret(proc_body, stacks, defs)
    last_stacks = [ pop(WS(n_stacks)), RS(n_stacks) ]

    return (last_stacks, n_defs) if top(WS(n_stacks)) == 1 \
           else exec_begin_until(proc_body, last_stacks, n_defs)

  return exec_begin_until

def exec_if_else_then_for(interpret):
  def split_tokens_into_cond_if_else(tokens):
    seq1, exp_rest = split_val(tokens, 'else')
    seq2 = exp_rest[1:]
    return (seq1, seq2)
  
  def exec_if_else_then(proc_body, stacks, defs):
    if empty(proc_body): ## tratando o caso onde o corpo do `if..then` não foi definido
      return (stacks, defs)

    seq_if, seq_else = split_tokens_into_cond_if_else(proc_body)
    last_stacks = [ pop(WS(stacks)), RS(stacks) ]

    return interpret(seq_if, last_stacks, defs) if top(WS(stacks)) == 1 \
           else interpret(seq_else, last_stacks, defs)
    
  return exec_if_else_then

  

def interpret(tokens, stacks, defs):
  ## Interpret does not change stacks and defs if no tokens are provided
  if not tokens:
    return stacks, defs

  ## If number, stacks it
  elif is_number(tokens[0]):
    stacks[0] = push(stacks[0], float(tokens[0]))

  ## If :, get definition (everything between : and ;) and stores in defs
  elif tokens[0] == ':' and ';' in tokens:
    proc_body, tokens_remains = split_val(tokens[1:], ';') 
    #return stacks, new_def(defs, word = proc_body[0], seq = proc_body[1:])
    return interpret(tokens_remains[1:], stacks, new_def(defs, word = proc_body[0], seq = proc_body[1:]))

  ## If .", gets every word until " and display them
  elif tokens[0] == '."':
    string_body, tokens = split_val(tokens[1:], '"') 
    print(' '.join(string_body), end='')

  ## If cr, emits \n
  elif tokens[0] == 'cr':
    print('\n', end='')

  ## If something in primitives, run it
  elif tokens[0] in primitives:
    stacks = primitives[tokens[0]](stacks)

  ######################### RESPOSTAS DA QUESTÃO 3-7 #########################

  elif tokens[0] == 'begin' and 'until' in tokens: ## não permite a definição multi line do `begin..until`
    proc_body, tokens_remains = split_val(tokens[1:], 'until')
    n_stacks, n_defs = exec_begin_until_for(interpret)(proc_body, stacks, defs)
    return interpret(tokens_remains[1:], n_stacks, n_defs)
  
  elif 'if' in tokens and 'then' in tokens: ## não permite a definição multi line do `if..else..then`
    proc_body, tokens_remains = split_val(tokens[1:], 'then')
    n_stacks, n_defs = exec_if_else_then_for(interpret)(proc_body, stacks, defs)
    return interpret(tokens_remains[1:], n_stacks, n_defs)

  ############################################################################
  
  ## If something in defs, run it
  elif tokens[0] in defs:
    stacks, defs = interpret(defs[tokens[0]], stacks, defs)

  ## Well, I dont understand you
  elif tokens[0]: ## apenas se não for vazio
    print('  Unknown word: [%s]' % tokens[0])

  return interpret(tokens[1:], stacks, defs)

# %% [markdown]
# Abaixo, um pequeno código de interação com o usuário:

# %%
def lforth_r(stacks, defs):
  uin = raw_input('\n$ ') #input('\n$ ')
  if uin == 'quit' or uin == 'q':
    return
  n_stacks, n_defs = interpret(uin.split(' '), stacks, defs)
  return lforth_r(n_stacks, n_defs)

def lforth():
  print('ulikeForth. Type "quit" or "q" to exit')
  lforth_r(stacks = [[], []], defs = dict([]))
  
lforth()

# %% [markdown]
# #### Questão 3-8: programando em $\mu$Forth
# Usando o seu interpretador, crie as seguintes palavras em $\mu$Forth:
# * **`par`**: checa se o valor no topo da pilha é par, ex: **`2 par .`** deve imprimir `1`.
# * **`w2r`**: transfere todas as palavras na pilha de trabalho para a pilha de resultado, ex: **`10 20 30 40 w2r disp`** deve exibir os elementos `40 30 20` e `10` no topo da pilha de resultados.
# * **`clear`**: limpa a pilha de trabalho, ex: **`1 2 3 4 clear disp`** deve exibir a pilha de trabalho vazia.
# * **`len`**: conta o número de elementos atualmente na pilha, ex: **`clear 10 20 30 40 len .`** deve imprimir `4`; **`clear len`** deve imprimir `0`.

# %%
def _par(stacks):
  'checa se o valor no topo da pilha de trabalho é par'
  if empty( WS(stacks) ):
    return stacks[:]
  result_stack = una_op(WS(stacks), lambda x: x % 2 == 0)
  return [ push( pop(result_stack), +top(result_stack) ),
           RS(stacks) ]

def _w2r(stacks):
  'transfere todas as palavras na pilha de trabalho para a pilha de resultados'
  move = lambda s1, s2: s2 if empty(s1) \
                        else move( pop(s1), push(s2, top(s1)) )
  return [ [],
          move( WS(stacks), RS(stacks) ) ]

def _clear(stacks):
  'limpa a pilha de trabalho'
  return [ [],
           RS(stacks) ]

def _len(stacks):
  'conta o número de palavras na pilha de trabalho (sem desempilhar), empilhando o resultado'
  def sum_until_empty(s, l=0): ## usando tail recursion
    return l if empty(s) else sum_until_empty(pop(s), l + 1)

  return [ push( WS(stacks), sum_until_empty(WS(stacks)) ),
           RS(stacks) ]

# %% [markdown]
# ##### dicionário `primitives` atualizado:

# %%
primitives = {
  # The two Forth stacks (working and results) are represented by a list with two values.
  # Each Forth primitive receives the two stacks, modifying them if necessary.
  # -- dot: calls dot to show working stack top value (value is consumed)
  '.':      lambda stacks: [ dot(WS(stacks)), RS(stacks) ],
  # -- drop: drops element from working stack
  'drop':   lambda stacks: [ pop(WS(stacks)), RS(stacks) ],
  # -- rempty: pushes 1 to working stack if result stack is empty; 0, otherwise 
  'rempty': lambda stacks: [ push(WS(stacks), int(empty(RS(stacks)))), RS(stacks) ],
  # -- sqrt: substitutes the top of the working stack value by its square root 
  'sqrt':   lambda stacks: [ una_op(WS(stacks), sqrt), RS(stacks) ],
  # -- +: substitutes the two top values in working stack by their sum
  '+':      lambda stacks: [ bin_op(WS(stacks), lambda x,y: x+y), RS(stacks) ],

  ######################### RESPOSTAS DA QUESTÃO 3-6 #########################
    
  # -- disp: exibe na tela as pilhas de trabalho e de resultados (sem consumir)
  'disp': _disp,
  # -- -: realiza a subtração na pilha de resultados
  '-': _sub,
  # -- *: realiza a mutiplicação na pilha de resultados
  '*': _mul,
  # -- /: realiza a divisão na pilha de resultados
  '/': _div,
  # -- %: realiza a operação de resto (MOD) na pilha de resultados
  '%': _mod,
  # -- >: empilha 0 ou 1 de acordo com a saída da operação lógica MAIOR QUE
  '>': _greater_than,
  # -- <: empilha 0 ou 1 de acordo com a saída da operação lógica MAIOR QUE
  '<': _less_than,
  # -- =: empilha 1 se os dois valores do topo forem iguais ou 0 caso contrário
  '=': _equal,
  # -- or: empilha 0 ou 1 de acordo com a saída do operador relacional OR
  'or': _or,
  # -- and: empilha 0 ou 1 de acordo com a saída do operador relacional NOT
  'and': _and,
  # -- not: empilha 0 ou 1 de acordo com a saída do operador relacional NOT
  'not': _not,
  # -- empty: empilha 1 se pilha de trabalho está vazia (0, caso contrário)
  'empty': _empty,
  # -- swap: troca valores no topo da pilha de trabalho
  'swap': _swap,
  # -- dup: duplica o valor do topo da pilha de trabalho
  'dup': _dup,
  # -- roll: move o n-ésimo valor por topo (1 roll com 5 6 7 -> 6 5 7)
  'roll': _roll,
  # -- >r: move o topo da pilha de trabalho pra pilha de resultados
  '>r': _move_ws_to_rs,
  # -- r>: move o topo da pilha de resultados pra pilha de trabalho
  'r>': _move_rs_to_ws,
  # -- r@: copia o topo da pilha de trabalho pra pilha de resultados (sem consumir)
  'r@': _copy_ws_to_rs,
    
  ######################### RESPOSTAS DA QUESTÃO 3-8 #########################

  # -- w2r: transfere todas as palavras na pilha de trabalho para a pilha de resultados
  'w2r': _w2r,
  # -- par: checa se o valor no topo da pilha é par
  'par': _par,
  # -- clear: limpa a pilha de trabalho
  'clear': _clear,
  # -- len: conta o número de elementos atualmente na pilha
  'len': _len
}

# %% [markdown]
# #### Questão 3-9: comparação de linguages
# Baseado em sua experiência com Python Funcional, a compare com Forth, considerando os seguintes critérios:
# * Simplicidade, Ortogonalidade, Tipos de Dados, Projeto de Sintaxe, Suporte à Abstração, Expressividade, Checagem de Tipos, Manipulação de Exceções e Restrição de Aliases
# * Legibilidade, capacidade de escrita e confiabilidade

# %% [markdown]
# | | | Legibilidade | Escrita | Confiabilidade |
# |:-:|:-|:------------:|:-------:|:--------------:|
# | `1` | Simplicidade                       | **X** | **X** | **X**
# | `2` | Ortogonalidade                 | **X** | **X** | **X**
# | `3` | Tipos de Dados                 | **X** | **X** | **X**
# | `4` | Projeto de Sintaxe         | **X** | **X** | **X**
# | `5` | Suporte à abstração       | | **X** | **X**
# | `6` | Expressividade                 | | **X** | **X**
# | `7` | Checagem de Tipos           | | | **X**
# | `8` | Manipulação de Exceção | | | **X**
# | `9` | Restrição de _Aliases_   | | | **X**

# %% [markdown]
# Apesar da **simplicidade** global em ambos, o maior grau de **ortogonalidade** do Forth é mais simples que o python funcional, apesar de fornecer um número maior de componentes básicos.
#
# O Forth não possui uma facilidade para definir **tipos de dados**, visto seu alto grau de ortogonalidade. De modo que, por exemplo, um booleano é representado pela convenção númerica. O mesmo não acontece no Python, melhorando a legibilidade.
#
# Em relação à **sintaxe**, apesar da simplicidade adotada pelo Forth, a legibilidade é prejudicada. Ao usar grupos de palavras reservadas como delimitadores de instruções de controle, o número de palavras reservadas aumenta. No Python funcional, muitas instruções indicam sua funcionalidade o que não ocorre no Forth, só que, por exemplo, "r>" tem um significado implícito nada intuitivo. A identação como definição de escopo não prejudica a legibilidade se as funções forem simples (e curtas em linhas), como o esperado. Já a ausência dessa definição no Forth, a torna mais "aceitável" e fácil de entender, já que as instruções são cadeias de palavras e somente isso.
#
# A **capacidade de abstração** do processo em Forth, é simples e consistente, muito devido à ortogonalidade facilitando a escrita. Porém, seria necessário cários níveis de abstrações para definir uma estrutura mais complexa, como uma árvore binária. O mesmo problema ocorre no Python funcional, porém de forma menos complexa de lidar.
#
# O Python funcional tem geradores que permitem que várias computações possam ser realizadas em um programa. O Forth também tem essa **expressividade**, porém, a capacidade de escrita é mais prejudicada.
#
# Como o Forth trabalha com pilhas de números, a **checagem de tipos** se torna irrelevante. Enquanto no Python funcional a verificação ocorre de maneira indepentendete, mas, ainda pode ser reforçada usando-se funções que acessam meta informações de um elemento.
#
# Pyhton funcional usa um mecanismo para **manipular exceções** que intercepta erros em tempo de execução, porém a confiabilidade se reduz à isto. Já o Forth não oferece tal suporte, assumindo que tudo deve ocorrer de maneira esperada.
